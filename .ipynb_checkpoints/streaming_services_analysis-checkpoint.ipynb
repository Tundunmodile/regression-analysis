# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter 

sns.set_style('darkgrid')

# %%
class DataAnalysis():
    def __init__(self, data):
        self.df = pd.read_csv(data, index_col=0)
        
    def display_data(self):
        print(self.df.head(10))
    
    def display_col(self, column_name):
        return self.df[column_name].dropna().values
        
    def data_counter(self, column_name, limit):
        return dict(Counter(self.df[column_name].dropna().values).most_common(limit))
    
    def counter(self, column_name):
        return dict(Counter(self.df[column_name].dropna().values))

# %%
netflix = DataAnalysis("netflix_titles.csv")
#netflix.display_data()
netflix_data = netflix.data_counter('country',10)
movie_count = print("Total Number of Netflix Movies:", len(netflix.counter('title')))
# Out:
# Total Number of Netflix Movies: 5377

# %%
hulu = DataAnalysis("hulu_titles.csv")
#hulu.display_data()
hulu_data = hulu.data_counter('country',10)
movie_count = print("Total Number of Hulu Movies:", len(hulu.counter('title')))
# Out:
# Total Number of Hulu Movies: 903

# %%
#the top 20 countries of movies on netlix
print(netflix_data)
countries = netflix_data.keys()
freqs = netflix_data.values()

#bar chart of top 20 countries of movies on netflix
plt.bar(countries, freqs, color='red')
plt.xticks(rotation=90)
plt.show()

#the top 20 countries of movies on hulu
print(hulu_data)
countries = hulu_data.keys()
freqs = hulu_data.values()

#bar chart of top 20 countries of movies on hulu
plt.bar(countries, freqs, color='green')
plt.xticks(rotation=90)
plt.show()
# Out:
# {'United States': 1850, 'India': 852, 'United Kingdom': 193, 'Canada': 118, 'Egypt': 89, 'Spain': 89, 'Turkey': 73, 'Philippines': 70, 'France': 69, 'Japan': 69}
# {'United States': 502, 'United Kingdom': 38, 'Canada': 25, 'Japan': 20, 'United States,United Kingdom': 15, 'Canada,United States': 14, 'United Kingdom,United States': 14, 'France': 12, 'United States,Canada': 11, 'South Korea': 11}

# %%
#directors with the most movies in Netflix
netflix_director_data = netflix.data_counter('director',100)
print(netflix_director_data)

s = ''
for val in netflix_director_data:
    s += val

wordcloud = WordCloud(max_font_size=50, max_words=200, background_color="red").generate(s)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# {'Raúl Campos, Jan Suter': 18, 'Marcus Raboy': 15, 'Jay Karas': 14, 'Cathy Garcia-Molina': 13, 'Youssef Chahine': 12, 'Martin Scorsese': 12, 'Jay Chapman': 12, 'Steven Spielberg': 10, 'David Dhawan': 9, 'Kunle Afolayan': 8, 'Hakan Algül': 8, 'Shannon Hartman': 8, 'Johnnie To': 8, 'Lance Bangs': 8, 'Robert Rodriguez': 8, 'Ozan Açıktan': 7, 'McG': 7, 'Justin G. Dyck': 7, 'S.S. Rajamouli': 7, 'Omoni Oboli': 7, 'Ryan Polito': 7, 'Don Michael Paul': 7, 'Fernando Ayllón': 7, 'Quentin Tarantino': 7, 'Yılmaz Erdoğan': 7, 'Ram Gopal Varma': 6, 'Rajkumar Santoshi': 6, 'Ron Howard': 6, 'Wenn V. Deramas': 6, 'Troy Miller': 6, 'Vlad Yudin': 6, 'Anees Bazmee': 6, 'Joey So': 6, 'Noah Baumbach': 6, 'Sameh Abdulaziz': 6, 'Steven Soderbergh': 6, 'Imtiaz Ali': 6, 'Sooraj R. Barjatya': 6, 'Ashutosh Gowariker': 6, 'Hanung Bramantyo': 6, 'Robert Vince': 6, 'Matt Askem': 6, 'Nagesh Kukunoor': 5, 'Vishal Bhardwaj': 5, 'Rajiv Mehra': 5, 'Prakash Jha': 5, 'Umesh Mehra': 5, 'Thierry Donard': 5, 'Jay Roach': 5,
# ...

# %%
#directors with the most movies in hulu
hulu_director_data = hulu.data_counter('director',100)
print(hulu_director_data)
s = ''
for val in hulu_director_data:
    s += val

wordcloud = WordCloud(max_font_size=50, max_words=200, background_color="green").generate(s)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# {'Savage Steve Holland': 5, 'Tyler Perry': 5, 'Richard Rich': 4, 'Ron Myrick': 3, 'Bong Joon Ho': 3, 'Michael Apted': 3, 'Alan Metter': 3, 'William Lau': 3, 'Kunihiko Yuyama': 3, 'Gabriela Cowperthwaite': 2, 'Roland Emmerich': 2, 'Ivan Reitman': 2, 'Christopher Nolan': 2, 'Gus Van Sant': 2, 'Quentin Tarantino': 2, 'Rob Reiner': 2, 'Matt Ross': 2, 'Hirokazu Koreeda': 2, 'Nicholas Meyer': 2, 'Gore Verbinski': 2, 'Lars von Trier': 2, 'Richard Eyre': 2, 'Ali Abbasi': 2, 'Bill Condon': 2, 'Bahman Ghobadi': 2, 'Harald Zwart': 2, 'Sean Ellis': 2, 'Jesse Peretz': 2, 'Mikkel Nørgaard': 2, 'Brett Haley': 2, 'Edward Zwick': 2, 'Stephen Cone': 2, 'Joe Swanberg': 2, 'Michael Almereyda': 2, 'Todd Berger': 2, 'John McPhail': 2, 'Karyn Kusama': 2, 'Don Argott,Sheena M. Joyce': 2, 'Sang-soo Im': 2, 'Brady Corbet': 2, 'Rory Kennedy': 2, 'Christophe Honoré': 2, 'Scott Speer': 2, 'Bobby Roe': 2, 'Sam Peckinpah': 2, 'Martin Owen': 2, 'Jason Murphy': 2, 'Craig George': 2, 'David Gelb': 1, 'Ruben Östlund':
# ...

# %%
#most popular genres in Netflix
netflix_genre_data = netflix.data_counter('genre',5)
print(netflix_genre_data)
genre = netflix_genre_data.keys()
number = netflix_genre_data.values()

#bar chart of popular genres in netflix
plt.bar(genre, number, color='red')
plt.xticks(rotation=90)
plt.show()

#most popular genres in hulu
hulu_genre_data = hulu.data_counter('genre',5)
print(hulu_genre_data)
genre = hulu_genre_data.keys()
number = hulu_genre_data.values()

#bar chart of popular genres in hulu
plt.bar(genre, number, color='green')
plt.xticks(rotation=90)
plt.show()
# Out:
# {'Documentaries': 334, 'Stand-Up Comedy': 321, 'Dramas, International Movies': 320, 'Comedies, Dramas, International Movies': 243, 'Dramas, Independent Movies, International Movies': 215}
# {'Documentary': 75, 'Drama': 44, 'Comedy,Drama': 38, 'Comedy': 36, 'Drama,Romance': 30}

# %%
text = netflix.data_counter('cast',10)
print(text)
s = ''
for val in text:
    s += val

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(s)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# {'Samuel West': 10, 'Jeff Dunham': 7, 'Kevin Hart': 6, 'Craig Sechler': 6, 'Bill Burr': 5, 'David Attenborough': 5, 'Iliza Shlesinger': 5, 'Jim Gaffigan': 5, 'Michela Luci, Jamie Watson, Eric Peterson, Anna Claire Bartlam, Nicolas Aqui, Cory Doran, Julie Lemieux, Derek McGrath': 5, 'Prabhas, Rana Daggubati, Anushka Shetty, Tamannaah Bhatia, Sathyaraj, Nassar, Ramya Krishnan, Sudeep': 4}
